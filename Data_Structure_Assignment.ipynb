# %% [markdown]
# #**Data** **Types** **and** **Structures** **Questions**

# %% [markdown]
# 1. What are data structures, and why are they important?
# - A data structure is used for organizing, processing and storing data. They are important because they make code easier to understand.

# %% [markdown]
# 2. Explain the difference between mutable and immutable data types with examples?
# - Mutable data types can be changed after creation.
# - Immutable data types cannot be changed after creation.

# %%
#Mutable e.g.
num = [1,2,3]
num.append(4)
num[0]=100
print(num)
# Out:
# [100, 2, 3, 4]

# %%
#Immutable e.g.
number = (1,2,3)
number.append(4)
number[0]=100
print(number)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2127434814.py in <cell line: 0>()
#       1 #Immutable e.g.
#       2 number = (1,2,3)
# ----> 3 number.append(4)
#       4 number[0]=100
#       5 print(number)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# 3. What are the main difference betweeen lists and tuples?
# - The main difference is that lists are mutable and tuples are immutable.

# %% [markdown]
# 4. Describe how dictionaries store data.
# - Dictionaries store data in a key-value pair.

# %% [markdown]
# 5. Why might you use a set insted of a list in Python?
# - We can use set instead of list when we want unique elements only.

# %% [markdown]
# 6. What is a String in Python. and how is it different from a list?
# - A String in Python is a sequence of characters enclosed in single quotes, double quotes, or triple quotes. String is immutable while list is mutable.

# %% [markdown]
# 7. How do tuples ensure data integrity in Python?
# - The immutability is the key reason tuples help ensure data integrity in Python.

# %% [markdown]
# 8. What is a hash table, and how does it relate to dictionaries in Python?
# - A hash table is a data structure that stores data in key-value pairs.
# - A dictionary in Python is implemented internally using a hash table.

# %% [markdown]
# 9. Can lists contain different data types in Python?
# - Yes, lists can contain different data types in Python.

# %% [markdown]
# 10. Explain why strings are immutable in Python.
# - Strings are immutable in Python for better efficiency and performance.

# %% [markdown]
# 11. What advantages do dictionaries offer over lists for certain tasks?
# - Dictionaries store data as key-value pairs.
# - Dictionaries provide fast lookups by a key.

# %% [markdown]
# 12. Describe a scenario where using a tuple would be preferable over a list.
# - Returning results from a function where you only read, not modify, the values.

# %% [markdown]
# 13. How do sets handle duplicate values in Python?
# - Sets automatically remove duplicates, only unique elements are kept.
# - Duplicate insertions are ignored silently.

# %% [markdown]
# 14. How does the "in" keyword works differently for lists and dictionaries?
# - When you use in with a list, Python checks if the given value is present as an element in the list.
# - When you use in with a dictionary, Python checks only the keys, not the values.

# %% [markdown]
# 15. Can you modify the elements of a tuple? Explain why or why not.
# - No, you cannot directly modify the elements of a tuple.
# - Tuples are Immutable.

# %% [markdown]
# 16. What is a nested dictionary, and give an example of its use case?
# - A nested dictionary is a dictionary inside another dictionary. An example of its use case:

# %%
#E.g. :-
students = {
    "01": {"name": "Tushar", "age": 21, "subject": "Maths"},
    "02": {"name": "Lakshay", "age": 21, "subject": "Physics"}
}

# %% [markdown]
# 18. In what situations are lists preferred over dictionaries?
# - Lists can store multiple occurrences of the same value. Dictionaries require unique keys.
# - Lists allow access by index, which is fast.

# %% [markdown]
# 19. Why are dictionaries considered unordered, and how does that affect data retrieval?
# - Dictionaries were considered unordered because they use a hash table for fast key lookups.

# %% [markdown]
# 20. Explain the difference between a list and a dictionary in terms of data retrieval.
# - In list, you retrieve elements using index or by scanning through the list.
# - In dictionary, you retieve elements using keys, not index.

# %% [markdown]
# #**Practical** **Questions**

# %%
#1. Write a code to create a string with your name and print it.
my_name = "Tushar Thakur"
print(my_name)
# Out:
# Tushar Thakur

# %%
#2. Write a code to find the length of the string "Hello World".
string = "Hello World"
print(len(string))
# Out:
# 11

# %%
#3. Write a code to slice the first three characters from the string "Python Programming".
string = "Python Programming"
string[3::]
# Out:
# 'hon Programming'

# %%
#4. Write a code to convert the string "hello" to uppercase.
string = "hello"
string.upper()
# Out:
# 'HELLO'

# %%
#5. Write a code to replace the word "apple" with "orange" in the string "I like apple".
string = "I like apple"
string.replace("apple", "orange")
# Out:
# 'I like orange'

# %%
#6.  Write a code to create a list with numbers 1 to 5 and print it.
list = [1,2,3,4,5]
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
#7. Write a code to append the number 10 to the list [1, 2, 3, 4].
list = [1,2,3,4]
list.append(10)
print(list)
# Out:
# [1, 2, 3, 4, 10]

# %%
#8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].
list = [1,2,3,4,5]
list.remove(3)
print(list)
# Out:
# [1, 2, 4, 5]

# %%
#9. Write a code to access the second element in the list ['a', 'b', 'c', 'd'].
list = ['a', 'b', 'c', 'd']
list[1]
# Out:
# 'b'

# %%
#10. Write a code to reverse the list [10, 20, 30, 40, 50].
list = [10, 20, 30, 40, 50]
list.reverse()
print(list)
# Out:
# [50, 40, 30, 20, 10]

# %%
#11. Write a code to create a tuple with the elements 100, 200, 300 and print it.
tuple = (100, 200, 300)
print(tuple)
# Out:
# (100, 200, 300)

# %%
#12.  Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').
tuple = ('red', 'green', 'blue', 'yellow')
tuple[-2]
# Out:
# 'blue'

# %%
#13. Write a code to find the minimum number in the tuple (10, 20, 5, 15).
tuple = (10, 20, 5, 15)
min(tuple)
# Out:
# 5

# %%
#14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
tuple = ('dog', 'cat', 'rabbit')
tuple.index('cat')
# Out:
# 1

# %%
#15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.
tuple = ("apple", "banana", "orange")
"kiwi" in tuple
# Out:
# False

# %%
#16. Write a code to create a set with the elements 'a', 'b', 'c' and print it.
set = {'a', 'b', 'c'}
print(set)
# Out:
# {'c', 'b', 'a'}

# %%
#17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
set = {1, 2, 3, 4, 5}
set.clear()
print(set)
# Out:
# set()

# %%
#18. Write a code to remove the element 4 from the set {1, 2, 3, 4}.
set = {1, 2, 3, 4}
set.remove(4)
print(set)
# Out:
# {1, 2, 3}

# %%
#19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.
set1 = {1, 2, 3}
set2 = {3, 4, 5}
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5}

# %%
#20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.
set1 = {1, 2, 3}
set2 = {2, 3, 4}
set1.intersection(set2)
# Out:
# {2, 3}

# %%
#21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
dict = {"name": "Tushar", "age": 21, "city": "Kullu"}
print(dict)
# Out:
# {'name': 'Tushar', 'age': 21, 'city': 'Kullu'}

# %%
#22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.
dict = {'name': 'John', 'age': 25}
dict["country"] = "USA"
print(dict)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
#23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.
dict = {'name': 'Alice', 'age': 30}
dict["name"]
# Out:
# 'Alice'

# %%
#24. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
dict = {'name': 'Bob', 'age': 22, 'city': 'New York'}
dict.pop("age")
print(dict)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
#25. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.
dict = {'name': 'Alice', 'city': 'Paris'}
"city" in dict
# Out:
# True

# %%
#26. Write a code to create a list, a tuple, and a dictionary, and print them all.
list = [1,2,3]
tuple = (1,2,3)
dict = {"name": "Tushar", "age": 21}
print(list)
print(tuple)
print(dict)
# Out:
# [1, 2, 3]
# (1, 2, 3)
# {'name': 'Tushar', 'age': 21}

# %%
#27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.
import random
list = [random.randint(1,100) for i in range(5)]
list.sort()
print(list)
# Out:
# [9, 22, 51, 66, 80]

# %%
#28. Write a code to create a list with strings and print the element at the third index.
list = ["apple", "banana", "orange", "kiwi"]
list[2]
# Out:
# 'orange'

# %%
#29. Write a code to combine two dictionaries into one and print the result.
dict1 = {"name": "Tushar", "age": 21}
dict2 = {"city": "Kullu", "country": "India"}
dict1.update(dict2)
print(dict1)
# Out:
# {'name': 'Tushar', 'age': 21, 'city': 'Kullu', 'country': 'India'}

# %%
#30. Write a code to convert a list of strings into a set.
list1 = ["apple", "banana", "orange"]
set1 = set(list1)
print(set1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4253360547.py in <cell line: 0>()
#       1 #30. Write a code to convert a list of strings into a set.
#       2 list1 = ["apple", "banana", "orange"]
# ----> 3 set1 = set(list1)
#       4 print(set1)
#
# TypeError: 'set' object is not callable
